# %% [markdown]
# # Violent word analysis

# %% [markdown]
# In this notebook, we will apply a word counter using various lists of violent terms to analyze the plot data in the clean dataset.

# %% [markdown]
# ### Imports

# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Add the project root directory (not src) to sys.path
sys.path.append(os.path.abspath("../data/"))

# Now import the DataLoader class
from data_loading import DataLoader

raw = '../../data/RAW/'
clean = '../../data/CLEAN'

# %%
# Add the directory containing the script to sys.path
sys.path.append(os.path.abspath("../model"))

# Now you can import the script like a module
from Word_counter import WordCounter

# %% [markdown]
# ## Load the data

# %%
#load raw data
data_loader = DataLoader(raw,clean)

Test_set_data = True
if Test_set_data :
    MovieData = data_loader.plot_data()
    ViolentLabel, ViolentData = data_loader.human_labelled_data()
    MovieData = MovieData.loc[ViolentData.index.unique()]
else :
    MovieData = data_loader.clean_movie_data()
# Out:
# load plot data
# /Users/djay/miniforge3/envs/ada/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
MovieData
# Out:
#                                                                  Plot
# Wikipedia movie ID
# 19286405            Panakkara Kudumbam is a movie about how human ...
# 6714641             After serving time for the attempted murder of...
# 27573594            Natsuki is a blind girl on whose testimony Tak...
# 25874731            Mistakenly believing that his brother-in-law's...
# 34954266            The genesis and metamorphoses of a film, from ...
# 19795169            A concert pianist, upon discovering she is dyi...
# 21787356            The story of Premi No. 1 revolves round Rohit ...
# 29651684            Photographer Eric Wright  visits his friend Da...
# 26015405            Tharadas is a ruthless smuggler whose uncle wa...
# 16994537            A mother discovers her daughter Susan is marry...
# 26363490            Roger  is publicly humiliated by Arthur  and p...
# 31419116            Balachandra Menon's character comes to investi...
# 9612611             Mysterious pilot, The Eagle, attempts to sabot...
# 20176769            A street orphan is framed for murder after unc...
# 26340503            {{Expand section}} Naked Massacre roughly tell...
# 33440196            An elderly watchmaker sees a beautiful young b...
# 19069841            Councillor Henry Parker, Secretary of Brightse...
# 34985277            The children of Kinshasa, using pencils and re...
# 4481850             Adam, a 23-year-old self-employed security tec...
# 24328926            It is the final weekend of summer and a group ...
# 6493287             A young woman trying to learn the identity of ...
# 15323823            {{expand section}} The film is set in Hanky Pa...
# 30465048            The film was based on Alexander's invasion of ...
# 34430499            Dark Rainbow is a musical love story. The cent...
# 18050522            Four actors go to a cabin in the woods to writ...
# 28852030            As the American Civil War begins, Ned Burton l...
# 2967223             Robert Crain is a German pacifist living in In...
# 27606335            After meeting her new home tutor, Kaoru become...
# 24398624            A group of five policemen engages in all sorts...
# 15124157            The film is an examination of libidinous baske...
# 8555713             The film follows Will Bastion  as he returns h...
# 22620682            Based on a novel, the film chronicles the live...
# 32109549            Raman Abdullah has Karan and Vignesh as friend...
# 26708843            The story, set during the Cold War, involves t...
# 29584842            In the Salem of 1692, a group of witches are b...
# 36039685            Detective Bobby Corcoran and his partner, Dete...
# 16494542            Richard Beck  is a police detective who believ...
# 34358984             *Robert Lowery as Lee Preston/Leland Bruce *H...
# 24165847            The film relates the fictionalized story of Ev...
# 5766332             The Times of Harvey Milk documents the politic...
# 14060163            Farewell to the Duman River is an action film ...
# 113454              The film tells the story of a mob hit man  and...
# 15217227            An erotic drama about a writer involved in a p...
# 28807164            The daughters of a domineering mother aspire t...
# 27286055            When a wealthy woman dies, she is buried with ...
# 24104622            The events of one day in the lives of a number...
# 14144257            NW Mounted Police Sgt. Ward is assigned to tra...
# 35004480            Traffic jams, commercial saturation and garbag...
# 3868321             Zach  is a soul collector, an angel who collec...
# 2295249             Theresa is one of the twelve jurors who have t...

# %% [markdown]
# ## Initialize the word counter

# %%
Word_Counter = WordCounter(data_loader,MovieData)

# %% [markdown]
# ## Perform word count and save the data

# %%
Count = Word_Counter.violent_word_count("All")
# Out:
# word count for the list : Physical_violence
# word count for the list : Psychological_violence
# total count
# calculate density
# done !

# %%
Count.head()
# Out:
#                     word_count_Physical_violence  \
# Wikipedia movie ID
# 113454                                         3
# 2295249                                        1
# 2967223                                        0
# 3868321                                        0
# 4481850                                       26
#
#                     word_count_Psychological_violence  total_count  \
# Wikipedia movie ID
# 113454                                              0           27
# 2295249                                             0           65
# 2967223                                             1           63
# 3868321                                             0           62
# 4481850                                             8         1165
#
#                     density word_count_Physical_violence  \
# Wikipedia movie ID
# 113454                                          0.111111
# 2295249                                         0.015385
# 2967223                                         0.000000
# 3868321                                         0.000000
# 4481850                                         0.022318
#
#                     density word_count_Psychological_violence
# Wikipedia movie ID
# 113454                                               0.000000
# 2295249                                              0.000000
# 2967223                                              0.015873
# 3868321                                              0.000000
# 4481850                                              0.006867

# %%
# save the result

if Test_set_data :
    Count.to_csv(clean + "/word_count_test.csv") 
else :
    Count.to_csv(clean + "/word_count.csv")
